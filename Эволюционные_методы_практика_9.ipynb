# %% [markdown]
# <a href="https://colab.research.google.com/github/alina-nnnn/Machine_learning/blob/main/%D0%AD%D0%B2%D0%BE%D0%BB%D1%8E%D1%86%D0%B8%D0%BE%D0%BD%D0%BD%D1%8B%D0%B5_%D0%BC%D0%B5%D1%82%D0%BE%D0%B4%D1%8B_%D0%BF%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D0%BA%D0%B0_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout
from sklearn.model_selection import train_test_split
import numpy

# random seed
numpy.random.seed(2)

# %%
# загрузка набора данных о диабете у индейцев, история болезни за последние 5 лет
dataset = numpy.loadtxt("prima-indians-diabetes.csv", delimiter=",")

# разделим на входные (X) и выходные (Y) переменные, разбивая данные CSV
X = dataset[:,:-1]
Y = dataset[:,-1]

# разделим X и y на обучающую и тестовую выборки
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
model = Sequential()
model.add(Dense(64, activation='relu', input_shape=(8,)))
model.add(Dense(32, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

model.fit(X_train, y_train, epochs=200, batch_size=32, verbose=2)
# Out:
# Epoch 1/200
# 20/20 - 1s - loss: 0.6655 - accuracy: 0.6156 - 1s/epoch - 60ms/step
# Epoch 2/200
# 20/20 - 0s - loss: 0.5992 - accuracy: 0.6710 - 38ms/epoch - 2ms/step
# Epoch 3/200
# 20/20 - 0s - loss: 0.5555 - accuracy: 0.7231 - 37ms/epoch - 2ms/step
# Epoch 4/200
# 20/20 - 0s - loss: 0.5134 - accuracy: 0.7524 - 36ms/epoch - 2ms/step
# Epoch 5/200
# 20/20 - 0s - loss: 0.5036 - accuracy: 0.7622 - 40ms/epoch - 2ms/step
# Epoch 6/200
# 20/20 - 0s - loss: 0.4702 - accuracy: 0.7736 - 35ms/epoch - 2ms/step
# Epoch 7/200
# 20/20 - 0s - loss: 0.4640 - accuracy: 0.7769 - 41ms/epoch - 2ms/step
# Epoch 8/200
# 20/20 - 0s - loss: 0.4620 - accuracy: 0.7720 - 38ms/epoch - 2ms/step
# Epoch 9/200
# 20/20 - 0s - loss: 0.4527 - accuracy: 0.7932 - 36ms/epoch - 2ms/step
# Epoch 10/200
# 20/20 - 0s - loss: 0.4427 - accuracy: 0.7818 - 36ms/epoch - 2ms/step
# Epoch 11/200
# 20/20 - 0s - loss: 0.4318 - accuracy: 0.8029 - 36ms/epoch - 2ms/step
# Epoch 12/200
# ...

# %%
# сохраняем модель
model.save('weights.h5')
